# %%
from google.colab import drive
drive.mount('/content/drive')


# Note: for this line to work, you have to create a shortcut to the CS 3300
# folder in your drive. idk if there is a better workaround
# %cd "/content/drive/MyDrive/INFO 3300"

# Imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/.shortcut-targets-by-id/1fWoSbZ4jYziYN4tjISHvtbUrJlsimHku/INFO 3300

# %%
# Load csv files
df1 = pd.read_csv("Project 2/merged_dataset.csv")
df1.columns
# Out:
# <ipython-input-10-34a4c04cd83a>:2: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv("Project 2/merged_dataset.csv")
# Index(['Unnamed: 0', 'COLLISION_ID', 'STATE_REGISTRATION', 'VEHICLE_TYPE',
#        'VEHICLE_YEAR', 'DRIVER_SEX', 'PRE_CRASH', 'CONTRIBUTING_FACTOR_1',
#        'CONTRIBUTING_FACTOR_2', 'PERSON_TYPE', 'PERSON_INJURY', 'PERSON_SEX',
#        'CRASH DATE', 'CRASH TIME', 'ZIP CODE', 'LATITUDE', 'LONGITUDE',
#        'NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED',
#        'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED',
#        'NUMBER OF CYCLIST INJURED', 'NUMBER OF CYCLIST KILLED',
#        'NUMBER OF MOTORIST INJURED', 'NUMBER OF MOTORIST KILLED',
#        'CONTRIBUTING FACTOR VEHICLE 1', 'CONTRIBUTING FACTOR VEHICLE 2',
#        'CONTRIBUTING FACTOR VEHICLE 3', 'CONTRIBUTING FACTOR VEHICLE 4',
#        'CONTRIBUTING FACTOR VEHICLE 5'],
#       dtype='object')

# %%
df1 = df1[['ZIP CODE', 'CONTRIBUTING_FACTOR_1', 'CONTRIBUTING_FACTOR_2',  'CONTRIBUTING FACTOR VEHICLE 1', 'CONTRIBUTING FACTOR VEHICLE 2',
       'CONTRIBUTING FACTOR VEHICLE 3', 'CONTRIBUTING FACTOR VEHICLE 4',
       'CONTRIBUTING FACTOR VEHICLE 5']]

# %%
pd.concat([df1['CONTRIBUTING_FACTOR_1'], df1['CONTRIBUTING_FACTOR_2']]).value_counts().head(40)
# Out:
# Unspecified                                              14626850
# Driver Inattention/Distraction                            2300189
# Following Too Closely                                      968292
# Failure to Yield Right-of-Way                              638821
# Passing or Lane Usage Improper                             434994
# Other Vehicular                                            385467
# Unsafe Lane Changing                                       357017
# Passing Too Closely                                        325638
# Unsafe Speed                                               281734
# Backing Unsafely                                           277704
# Driver Inexperience                                        255000
# Traffic Control Disregarded                                241021
# Turning Improperly                                         237883
# Reaction to Uninvolved Vehicle                             147061
# ...

# %%
pd.concat([df1['CONTRIBUTING FACTOR VEHICLE 1'], df1['CONTRIBUTING FACTOR VEHICLE 2'], df1['CONTRIBUTING FACTOR VEHICLE 3'], df1['CONTRIBUTING FACTOR VEHICLE 4'], df1['CONTRIBUTING FACTOR VEHICLE 5']]).value_counts().head(40)
# Out:
# Unspecified                                              14432302
# Driver Inattention/Distraction                            3652131
# Following Too Closely                                     1634665
# Failure to Yield Right-of-Way                              905828
# Passing or Lane Usage Improper                             626644
# Other Vehicular                                            625567
# Unsafe Lane Changing                                       477685
# Passing Too Closely                                        462195
# Backing Unsafely                                           457841
# Unsafe Speed                                               414991
# Traffic Control Disregarded                                358169
# Turning Improperly                                         323215
# Driver Inexperience                                        266372
# Reaction to Uninvolved Vehicle                             255453
# ...

# %%
factor_df = df1.melt(id_vars='ZIP CODE', value_vars=['CONTRIBUTING_FACTOR_1', 'CONTRIBUTING_FACTOR_2'], value_name='value')
