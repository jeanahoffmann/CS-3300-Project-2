# %%
from google.colab import drive
drive.mount('/content/drive')


# Note: for this line to work, you have to create a shortcut to the CS 3300
# folder in your drive. idk if there is a better workaround
# %cd "/content/drive/MyDrive/INFO 3300"

# Imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/INFO 3300

# %%
# Load csv files
df1 = pd.read_csv("Project 2/Raw Data/Motor_Vehicle_Collisions_-_Vehicles_20241107.csv")
df2 = pd.read_csv("Project 2/Raw Data/Motor_Vehicle_Collisions_-_Person_20241107.csv")
df3 = pd.read_csv("Project 2/Raw Data/Motor_Vehicle_Collisions_-_Crashes_20241107.csv")
# Out:
# <ipython-input-5-50d209d6f94b>:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv("Project 2/Raw Data/Motor_Vehicle_Collisions_-_Vehicles_20241107.csv")
# <ipython-input-5-50d209d6f94b>:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv("Project 2/Raw Data/Motor_Vehicle_Collisions_-_Crashes_20241107.csv")

# %%
df1.columns
# Out:
# Index(['UNIQUE_ID', 'COLLISION_ID', 'CRASH_DATE', 'CRASH_TIME', 'VEHICLE_ID',
#        'STATE_REGISTRATION', 'VEHICLE_TYPE', 'VEHICLE_MAKE', 'VEHICLE_MODEL',
#        'VEHICLE_YEAR', 'TRAVEL_DIRECTION', 'VEHICLE_OCCUPANTS', 'DRIVER_SEX',
#        'DRIVER_LICENSE_STATUS', 'DRIVER_LICENSE_JURISDICTION', 'PRE_CRASH',
#        'POINT_OF_IMPACT', 'VEHICLE_DAMAGE', 'VEHICLE_DAMAGE_1',
#        'VEHICLE_DAMAGE_2', 'VEHICLE_DAMAGE_3', 'PUBLIC_PROPERTY_DAMAGE',
#        'PUBLIC_PROPERTY_DAMAGE_TYPE', 'CONTRIBUTING_FACTOR_1',
#        'CONTRIBUTING_FACTOR_2'],
#       dtype='object')

# %%
df1_drop = df1.drop(["VEHICLE_ID", "VEHICLE_MAKE", "VEHICLE_MODEL", "VEHICLE_OCCUPANTS", "DRIVER_LICENSE_STATUS", "DRIVER_LICENSE_JURISDICTION", "POINT_OF_IMPACT", "VEHICLE_DAMAGE", "VEHICLE_DAMAGE_1", "VEHICLE_DAMAGE_2", "VEHICLE_DAMAGE_3", "PUBLIC_PROPERTY_DAMAGE", "TRAVEL_DIRECTION", "PUBLIC_PROPERTY_DAMAGE_TYPE", "CONTRIBUTING_FACTOR_2"], axis=1)
df1_drop
# Out:
#          UNIQUE_ID  COLLISION_ID  CRASH_DATE CRASH_TIME STATE_REGISTRATION  \
# 0         10385780        100201  09/07/2012       9:03                 NY
# 1         19140702       4213082  09/23/2019       8:15                 NY
# 2         14887647       3307608  10/02/2015      17:18                 NY
# 3         14889754       3308693  10/04/2015      20:34                 NY
# 4         14400270        297666  04/25/2013      21:15                 NY
# ...            ...           ...         ...        ...                ...
# 4280185   20776745       4768817  11/03/2024      23:05                 NY
# 4280186   20777430       4769107  11/02/2024      16:50                 NY
# 4280187   20776650       4768834  11/03/2024      16:50                 NY
# 4280188   20777532       4768964  10/22/2024      23:30                 NY
# 4280189   20776320       4768356  11/03/2024      13:21                 NY
#
# ...

# %%
df2.columns
# Out:
# Index(['UNIQUE_ID', 'COLLISION_ID', 'CRASH_DATE', 'CRASH_TIME', 'PERSON_ID',
#        'PERSON_TYPE', 'PERSON_INJURY', 'VEHICLE_ID', 'PERSON_AGE', 'EJECTION',
#        'EMOTIONAL_STATUS', 'BODILY_INJURY', 'POSITION_IN_VEHICLE',
#        'SAFETY_EQUIPMENT', 'PED_LOCATION', 'PED_ACTION', 'COMPLAINT',
#        'PED_ROLE', 'CONTRIBUTING_FACTOR_1', 'CONTRIBUTING_FACTOR_2',
#        'PERSON_SEX'],
#       dtype='object')

# %%
df2_drop = df2.drop(['UNIQUE_ID', 'PERSON_ID',
       'VEHICLE_ID', 'PERSON_AGE', 'EJECTION',
       'EMOTIONAL_STATUS', 'BODILY_INJURY', 'POSITION_IN_VEHICLE',
       'SAFETY_EQUIPMENT', 'PED_LOCATION', 'PED_ACTION', 'COMPLAINT',
       'PED_ROLE', 'CONTRIBUTING_FACTOR_1', 'CONTRIBUTING_FACTOR_2'], axis=1)
df2_drop
# Out:
#          COLLISION_ID  CRASH_DATE CRASH_TIME PERSON_TYPE PERSON_INJURY  \
# 0             4229554  10/26/2019       9:43    Occupant   Unspecified
# 1             4230587  10/25/2019      15:15    Occupant   Unspecified
# 2             4230550  10/26/2019      17:55    Occupant   Unspecified
# 3             3565527  11/21/2016      13:05    Occupant   Unspecified
# 4             4231168  10/25/2019      11:16    Occupant   Unspecified
# ...               ...         ...        ...         ...           ...
# 5518067       4768489  11/03/2024      21:59    Occupant   Unspecified
# 5518068       4768926  11/02/2024      14:00    Occupant   Unspecified
# 5518069       4769024  11/02/2024      15:50    Occupant   Unspecified
# 5518070       4768317  11/03/2024       1:00    Occupant   Unspecified
# 5518071       4768998  11/02/2024      20:00    Occupant   Unspecified
#
#         PERSON_SEX
# 0                U
# 1                F
# 2                M
# 3              NaN
# ...

# %%
df3.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
df3_drop = df3.drop(['BOROUGH', 'LOCATION', "ON STREET NAME", "CROSS STREET NAME", "OFF STREET NAME", "VEHICLE TYPE CODE 1", "VEHICLE TYPE CODE 2", "VEHICLE TYPE CODE 3", "VEHICLE TYPE CODE 4", "VEHICLE TYPE CODE 5"], axis=1 )
df3_drop
# Out:
#          CRASH DATE CRASH TIME ZIP CODE   LATITUDE  LONGITUDE  \
# 0        09/11/2021       2:39      NaN        NaN        NaN
# 1        03/26/2022      11:45      NaN        NaN        NaN
# 2        06/29/2022       6:55      NaN        NaN        NaN
# 3        09/11/2021       9:35  11208.0  40.667202 -73.866500
# 4        12/14/2021       8:13  11233.0  40.683304 -73.917274
# ...             ...        ...      ...        ...        ...
# 2132583  11/04/2024      21:52  11374.0  40.727695 -73.851776
# 2132584  11/04/2024      14:39  11219.0  40.631805 -73.988300
# 2132585  11/01/2024      22:00  10471.0  40.899567 -73.898040
# 2132586  11/04/2024       0:30      NaN  40.854100 -73.919106
# 2132587  11/04/2024       8:32  11234.0  40.619010 -73.925870
#
#          NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# 0                              2.0                       0.0
# 1                              1.0                       0.0
# ...

# %%
merge_df_test = (df1_drop.merge(df2_drop, on=['COLLISION_ID']))

# %%
merge_df_test = merge_df_test.merge(df3_drop, on = ['COLLISION_ID'])

# %%
merge_df_test.columns
# Out:
# Index(['UNIQUE_ID', 'COLLISION_ID', 'CRASH_DATE_x', 'CRASH_TIME_x',
#        'STATE_REGISTRATION', 'VEHICLE_TYPE', 'VEHICLE_YEAR', 'DRIVER_SEX',
#        'PRE_CRASH', 'CONTRIBUTING_FACTOR_1', 'CRASH_DATE_y', 'CRASH_TIME_y',
#        'PERSON_TYPE', 'PERSON_INJURY', 'PERSON_SEX', 'CRASH DATE',
#        'CRASH TIME', 'ZIP CODE', 'LATITUDE', 'LONGITUDE',
#        'NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED',
#        'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED',
#        'NUMBER OF CYCLIST INJURED', 'NUMBER OF CYCLIST KILLED',
#        'NUMBER OF MOTORIST INJURED', 'NUMBER OF MOTORIST KILLED',
#        'CONTRIBUTING FACTOR VEHICLE 1', 'CONTRIBUTING FACTOR VEHICLE 2',
#        'CONTRIBUTING FACTOR VEHICLE 3', 'CONTRIBUTING FACTOR VEHICLE 4',
#        'CONTRIBUTING FACTOR VEHICLE 5'],
#       dtype='object')

# %%
merge_df_test = merge_df_test.drop(["UNIQUE_ID", 'CRASH_DATE_x', 'CRASH_TIME_x', 'CRASH_DATE_y', 'CRASH_TIME_y'], axis=1)

# %%
merge_df_test.columns
# Out:
# Index(['COLLISION_ID', 'STATE_REGISTRATION', 'VEHICLE_TYPE', 'VEHICLE_YEAR',
#        'DRIVER_SEX', 'PRE_CRASH', 'CONTRIBUTING_FACTOR_1', 'PERSON_TYPE',
#        'PERSON_INJURY', 'PERSON_SEX', 'CRASH DATE', 'CRASH TIME', 'ZIP CODE',
#        'LATITUDE', 'LONGITUDE', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5'],
#       dtype='object')

# %%
merge_df_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ad29bf858db8> in <cell line: 1>()
# ----> 1 merge_df_test
#
# NameError: name 'merge_df_test' is not defined

# %%
merge_df_test.to_csv('Project 2/merged_dataset.csv')
